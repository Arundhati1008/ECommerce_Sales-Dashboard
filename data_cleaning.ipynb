# %%
import pandas as pd

# %%
"C:\Users\aditi\Downloads\online_retail.csv"

# %%
import pandas as pd
from sqlalchemy import create_engine

# read
df = pd.read_csv(r"C:\Users\aditi\Downloads\online_retail.csv")

# create revenue column
df['Revenue'] = df['Quantity'] * df['Price']

# connect to MySQL
engine = create_engine("mysql+pymysql://root:..password..@localhost/ecommerce_project")

# load data into SQL
df.to_sql("transactions", con=engine, if_exists="replace", index=False)

print("Data uploaded successfully!")
# Out:
# Data uploaded successfully!
